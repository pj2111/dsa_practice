# %% [markdown]
# <a href="https://colab.research.google.com/github/pj2111/dsa_practice/blob/main/DSA_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 1 - 10 aug

# %% [markdown]
# https://datastructurewithaipy-dhmexr7ukaudutklwjiawp.streamlit.app/
# https://blog.algomaster.io/p/15-leetcode-patterns
# https://blog.algomaster.io/p/how-i-mastered-data-structures-and-algorithms

# %% [markdown]
# ## Node

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node():
  def __init__(self, data):
    self.data = data
    self.next = None
  def __repr__(self) -> str:
    return f" Node with data as {self.data} and refers to {self.next}"

# %%
node1 = Node('abc')
node1
# Out:
#  Node with data as abc and refers to None

# %%
node1.data
# Out:
# 'abc'

# %%
node2 = Node(123)
node3 = Node([1,2,3])

# %%
node3
# Out:
#  Node with data as [1, 2, 3] and refers to None

# %%
node1.next=node2

# %%
node1
# Out:
#  Node with data as abc and refers to  Node with data as 123 and refers to None

# %%
node2.next=node3

# %%
node1
# Out:
#  Node with data as abc and refers to  Node with data as 123 and refers to  Node with data as [1, 2, 3] and refers to None

# %% [markdown]
# ## Linked List

# %%
class LinkedList:
  def __init__(self) -> None:
    self.head = None

# %%
l1= LinkedList()
l1

# %%
print(l1.head)
# Out:
# None

# %%
l1.head = node1

# %%
print(l1.head)
# Out:
#  Node with data as abc and refers to  Node with data as 123 and refers to  Node with data as [1, 2, 3] and refers to None

# %%
# type all the methods:
# experiment then
# comment the method

# %%
# review 1-2 simple problems
# in first 15 patterns

# Try experimenting to simulate a queue using python list

# %%
dict_a = {'a':1, 'b':2, 'c':3}
dict_b = {'f': 6, 'd':4}
# dict_comb = dict_a + dict_b #  type error- unsupported operand type +

# %%
dict_b.update(dict_a)
dict_b

# %%
keys_comb = list(dict_b.keys())
keys_comb.sort()
keys_comb
# Out:
# ['a', 'b', 'c', 'd', 'f']

# %%
dict1={}
for i in keys_comb:
  dict1[i]=dict_b.get(i)
dict1
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'f': 6}

# %%
dict_b.
# Out:
# {'f': 6, 'd': 4, 'a': 1, 'b': 2, 'c': 3}
